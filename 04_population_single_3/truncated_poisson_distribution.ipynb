# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zhimingkuang/Harvard-AM-115/blob/main/04_population_single_3/truncated_poisson_distribution.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import factorial

# %%
NVec = np.linspace(1,25,25)
lam_list = [1., 4., 10.]

# %%
# Customize for matplotlib
# If interested in the matplotlib object hierarchy, check: https://realpython.com/python-matplotlib-guide/
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['xtick.bottom'] = True
plt.rcParams['ytick.left'] = True
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['mathtext.default'] = 'regular'
# Change font size: http://www.futurile.net/2016/02/27/matplotlib-beautiful-plots-with-style/
plt.rcParams['font.size'] = 12
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 14
plt.rcParams['figure.titlesize'] = 20

# %%
# Plot solution
fig, ax = plt.subplots(1,1,figsize=(9,7))

for i,lam in enumerate(lam_list):
    pi_N = np.divide( np.divide(np.power(lam,NVec), factorial(NVec)), np.expm1(lam))
    ax.plot(NVec, pi_N/np.sum(pi_N), '-o', linewidth=1.5, mfc='none', ms=5.5, mew=1.5, label=r'$\lambda/\mu=%i$' % lam)
    
# Set title, legend, and axes labels
ax.set_title('truncated Poisson distributions')
ax.legend(loc='upper right')
ax.set_xlabel(r'$N$')
ax.set_ylabel(r'$P(x=N)$')

plt.show()
